# %%
import numpy as np
import pandas as pd
from pylab import rcParams
import seaborn as sb
import matplotlib.pyplot as plt
import collections
import sklearn

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %%
df = pd.read_csv('cleaned_tabular_data.csv')
print(df.shape)
df.info()
df.head(5)
# Out:
# (6311, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6311 non-null   int64
#  1   id            6311 non-null   object
#  2   product_name  6311 non-null   object
#  3   category1     6311 non-null   object
#  4   description   6311 non-null   object
#  5   price         6311 non-null   float64
#  6   location      6311 non-null   object
#  7   url           6311 non-null   object
#  8   page_id       6311 non-null   float64
#  9   date_posted   6311 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 493.2+ KB
#    Unnamed: 0                                    id  \
# 0           0  243809c0-9cfc-4486-ad12-3b7a16605ba9
# 1           1  1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 2           2  860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 3           3  59948726-29be-4b35-ade5-bb2fd7331856
# 4          12  5707be4f-49d9-4feb-b2c8-aa0868405c65
#
#                                         product_name  \
# 0  Mirror wall art | in Wokingham, Berkshire | Gu...
# 1  Stainless Steel Food Steamer | in Inverness, H...
# 2  Sun loungers | in Skegness, Lincolnshire | Gum...
# 3  Coffee side table from Ammunition ammo box hai...
# 4  Spotlights | in Newent, Gloucestershire | Gumtree
#
#                                            category1  \
# 0  Home & Garden / Dining, Living Room Furniture ...
# 1              Home & Garden / Other Household Goods
# 2  Home & Garden / Garden & Patio / Outdoor Setti...
# 3  Home & Garden / Dining, Living Room Furniture ...
# 4              Home & Garden / Other Household Goods
#
#                                          description    price  \
# 0  Mirror wall art. Posted by Nisha in Dining, Li...    500.0
# 1  Morphy Richard’s (model no 48755)Stainless ste...   2000.0
# 2  I have 2 of these - collection only as I don’t...   2000.0
# 3  Great reclaimed army ammunition box used as co...  11500.0
# 4  New in box not needed Spotlights . Posted by s...    900.0
#
#                   location                                                url  \
# 0     Wokingham, Berkshire  https://www.gumtree.com/p/mirrors-clocks-ornam...
# 1      Inverness, Highland  https://www.gumtree.com/p/other-household-good...
# 2   Skegness, Lincolnshire  https://www.gumtree.com/p/outdoor-settings-fur...
# 3       Radstock, Somerset  https://www.gumtree.com/p/other-dining-living-...
# 4  Newent, Gloucestershire  https://www.gumtree.com/p/other-household-good...
#
#         page_id date_posted
# 0  1.426705e+09  2022-02-26
# 1  1.426705e+09  2022-02-26
# 2  1.426705e+09  2022-02-26
# 3  1.426705e+09  2022-02-26
# 4  1.426705e+09  2022-02-26

# %%
# sb.pairplot(df) plots various 2D graphs - since df has many features, it will plot
